# %%
import pandas as pd
import tweepy
import plotly.express as px
#Authentication
consumer_key = 'YLcBQMSLFCHoJcGs5XLWZCfBC'
consumer_secret = 'oTFtiAejKDQ8MkbJTimDmpCZHVstyg8mIDK6kZz80cifmgIaWJ'
access_token = '1069049102317613056-wfSMqjCKxfrWAjUiG0Wrf9cIo3ghh4'
access_token_secret = 'gHeSGMFWOg28L4WhjpdacWzTEE1XJVLwBlcAow3eOT8X6'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# Get the followers count of the Twitter account
user = api.get_user(screen_name='vahidfarid')
followers_count = user.followers_count

# Get the followers count of the Twitter account for each day in the month
dates = []
followers = []
for i in range(30):
    dates.append(i+1)
    followers.append(followers_count)
    followers_count += api.get_user(screen_name='vahidfarid').followers_count

# Create a dataframe
df = pd.DataFrame({'date':dates, 'followers':followers})

# Plot the trend of getting followers
fig = px.line(df, x='date', y='followers', title='Trend of getting followers')
fig.show()
